# %%
import pandas as pd
import operator
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
es_encode_network = pd.DataFrame.from_csv("old_priors_formatted_subnetwork.tsv", sep='\t', index_col=False)
es_atac_network = pd.DataFrame.from_csv("formatted_subnetwork.tsv", sep='\t', index_col=False)
bbsr_atac_network = pd.DataFrame.from_csv("bbsr_formatted_subnetwork.tsv", sep='\t', index_col=False)
bbsr_encode_network = pd.DataFrame.from_csv("old_priors_bbsr_formatted_subnetwork.tsv", sep='\t', index_col=False)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-55-1991aa83a9db> in <module>()
#       3 bbsr_atac_network = pd.DataFrame.from_csv("bbsr_formatted_subnetwork.tsv", sep='\t', index_col=False)
#       4 bbsr_encode_network = pd.DataFrame.from_csv("old_priors_bbsr_formatted_subnetwork.tsv", sep='\t', index_col=False)
# ----> 5 atac_priors = pd.DataFrame.from_csv("~Data/hiv_dc/priors.tsv", sep='\t', index_col=False)
#       6 encode_priors = pd.DataFrame.from_csv("~Data/hiv_dc/old_priors.tsv", sep='\t', index_col=False)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in from_csv(cls, path, header, sep, index_col, parse_dates, encoding, tupleize_cols, infer_datetime_format)
#    1186                           parse_dates=parse_dates, index_col=index_col,
#    1187                           encoding=encoding, tupleize_cols=tupleize_cols,
# ...

# %% [markdown]
# Show Top TFs

# %%
from collections import Counter
es_encode_tfs = Counter(es_encode_network['regulator'].tolist())
es_atac_tfs = Counter(es_atac_network['regulator'].tolist())
bbsr_atac_tfs = Counter(bbsr_atac_network['regulator'].tolist())
bbsr_encode_tfs = Counter(bbsr_encode_network['regulator'].tolist())
sorted_es_encode_tfs = sorted(es_encode_tfs.items(), key=operator.itemgetter(1))[::-1]
sorted_es_atac_tfs = sorted(es_atac_tfs.items(), key=operator.itemgetter(1))[::-1]
sorted_bbsr_atac_tfs = sorted(bbsr_atac_tfs.items(), key=operator.itemgetter(1))[::-1]
sorted_bbsr_encode_tfs = sorted(bbsr_encode_tfs.items(), key=operator.itemgetter(1))[::-1]

# %%
es_encode_tfs['IRF7']
# Out:
# 73

# %%
es_atac_tfs['IRF7']
# Out:
# 71

# %%
bbsr_encode_tfs['IRF3']
# Out:
# 10

# %%
sorted_es_encode_tfs = sorted(es_encode_tfs.items(), key=operator.itemgetter(1))[::-1]

# %%
sorted_es_atac_tfs[1:500]

# %%
sorted_es_encode_tfs[1:500]

# %%
sorted_bbsr_encode_tfs[1:500]
# Out:
# [('IRF7', 30),
#  ('RELB', 28),
#  ('PLAGL1', 24),
#  ('ZNF263', 23),
#  ('IRF9', 21),
#  ('JUN', 20),
#  ('NFKB1', 19),
#  ('PROP1', 19),
#  ('RXRA', 18),
#  ('ELF1', 18),
#  ('KLF13', 18),
#  ('YY2', 18),
#  ('IRF1', 18),
#  ('THAP1', 18),
#  ('TFAP4', 18),
#  ('PPARD', 16),
#  ('HOXB3', 16),
#  ('MYC', 15),
#  ('THRB', 15),
#  ('ZFY', 15),
#  ('NFYB', 15),
#  ('GATA6', 15),
#  ('SP4', 15),
#  ('EGR1', 14),
#  ('IRF5', 14),
#  ('IRF2', 14),
#  ('T', 13),
#  ('FOXO3', 13),
#  ('ZNF589', 13),
#  ('EBF1', 13),
#  ('ESRRG', 13),
#  ('RFX2', 13),
#  ('PPARG', 13),
#  ('AHR', 13),
#  ('POU5F1', 12),
#  ('ZNF35', 12),
#  ('FOXA1', 12),
#  ('ZFX', 12),
#  ('TLX1', 12),
#  ('PBX3', 12),
#  ('VSX1', 12),
#  ('SOX11', 12),
#  ('TCF12', 12),
#  ('SP2', 12),
#  ('JUNB', 11),
#  ('ETV6', 11),
#  ('KLF16', 11),
#  ('FOXO1', 11),
#  ('ESR1', 11),
#  ('HOMEZ', 11),
#  ('EGR3', 11),
#  ('CREB5', 11),
#  ('RFX6', 11),
#  ('CTCF', 11),
#  ('ZNF524', 10),
#  ('NFKB2', 10),
#  ('ETV4', 10),
# ...

# %%
sorted_bbsr_atac_tfs[1:500]
# Out:
# [('ZNF263', 61),
#  ('PROP1', 51),
#  ('IRF7', 48),
#  ('RELB', 42),
#  ('NFKB1', 39),
#  ('YY2', 35),
#  ('RXRA', 26),
#  ('THAP1', 26),
#  ('PLAGL1', 26),
#  ('TFAP4', 25),
#  ('IRF2', 24),
#  ('IRF9', 23),
#  ('TERF2', 22),
#  ('IRF1', 21),
#  ('ELF1', 20),
#  ('THRB', 20),
#  ('MAFG', 19),
#  ('EBF1', 19),
#  ('REL', 19),
#  ('HOXB3', 19),
#  ('STAT5A', 18),
#  ('CTCF', 18),
#  ('MYC', 17),
#  ('ESRRG', 16),
#  ('FOXO3', 16),
#  ('JUN', 16),
#  ('IRF8', 16),
#  ('PPARD', 16),
#  ('RELA', 15),
#  ('PPARG', 15),
#  ('ZSCAN10', 15),
#  ('ZNF589', 14),
#  ('ELF2', 13),
#  ('EGR1', 13),
#  ('HSF2', 13),
#  ('CTCFL', 13),
#  ('NFYB', 13),
#  ('AHR', 13),
#  ('GATA6', 13),
#  ('ZFX', 13),
#  ('MLXIPL', 12),
#  ('TEF', 12),
#  ('FOXO1', 12),
#  ('ARNTL2', 12),
#  ('YY1', 12),
#  ('PAX6', 12),
#  ('KLF5', 12),
#  ('TP73', 12),
#  ('ETV7', 11),
#  ('MSC', 11),
#  ('TCF12', 11),
#  ('GLI3', 10),
#  ('JUNB', 10),
#  ('NR1I3', 10),
#  ('KLF16', 10),
#  ('ESR1', 10),
#  ('IRF5', 10),
# ...

# %%
sum([y for (x,y) in sorted_es_encode_tfs])
# Out:
# 1802

# %%
774, 756, 566, 372

1794,1802, 2161, 2553

# %%
, sorted_bbsr_atac_tfs[1:500], sorted_bbsr_encode_tfs[1:500]
