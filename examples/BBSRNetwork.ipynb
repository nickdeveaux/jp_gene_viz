# %% [markdown]
# # BBSR Network
#
# The following cells illustrate how to create a visualization for a
# transcriptional regulatory network using a data file in tab separated values
# format.
#
# Please see [the network overview documentation notebook](../doc/dNetwork%20widget%20overview.ipynb)
# for a description of the features of this widget.

# %%
# Uncomment to run without install in the Binder service.
import sys
if ".." not in sys.path:
    sys.path.append("..")

# %%
# Import the python implementation.
from jp_gene_viz import dNetwork

# %%
# Load the javascript "client side" support logic.
dNetwork.load_javascript_support()

# %%
# Load and display the network.
N = dNetwork.display_network("bbsr_formatted_subnetwork.tsv")
N.title_html.value = "DC subset regulatory network"
# Out:
# ('Reading network', 'bbsr_formatted_subnetwork.tsv')
# ('Loading saved layout', 'bbsr_formatted_subnetwork.tsv.layout.json')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c120593f4998> in <module>()
#       1 # Load and display the network.
# ----> 2 N = dNetwork.display_network("bbsr_formatted_subnetwork.tsv")
#       3 N.title_html.value = "DC subset regulatory network"
#
# //anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/dNetwork.pyc in display_network(filename, N, threshhold, save_layout, show)
#    1267     if threshhold:
#    1268         N.threshhold_slider.value = threshhold
# -> 1269     N.load_data(G, layout)
#    1270     if show:
#    1271         N.show()
#
# //anaconda/lib/python2.7/site-packages/jp_gene_viz-0.0.1-py2.7.egg/jp_gene_viz/dNetwork.pyc in load_data(self, graph, positions)
#     533         self.override_node_weights = None
#     534         ew = graph.edge_weights
# --> 535         maxw = max(abs(ew[e]) for e in ew) + 1.0
#     536         self.threshhold_slider.max = maxw
#     537         self.do_threshhold()
#
# ValueError: max() arg is an empty sequence

# %% [markdown]
# ### Custom colorization
#
# The following function demonstrates how the node and edge weights and network colorization
# may be adjusted to special purpose values.  Such colorization may be useful
# to highlight node or edge groups of special interest, or for other purposes.

# %%
# randomly reset the weight to integers 0..10

def adjust_colorization():
    import random
    G = N.display_graph
    nw = G.node_weights
    for node in nw.keys():
        nw[node] = random.randint(0, 10)
    ew = G.edge_weights
    for edge in ew.keys():
        ew[edge] = random.randint(0,10)
    # Use Emily's color scheme, please refer to the source code for more information.
    dNetwork.set_node_color_levels(N)
    dNetwork.set_edge_color_levels(N)
    # redraw
    N.draw()

# %%
# Uncomment to change the network colorization
#adjust_colorization()
